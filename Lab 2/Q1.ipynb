# %% [markdown]
# # Question 1

# %% [markdown]
# ## (a)

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
def f1(N):
    theta = 1.00/(2*np.pi)
    n = np.random.random_sample(N)
    n = n*9
    y = np.cos(0.2*np.pi*n + theta)
    print('mean= '+ str(y.mean()))
    plt.hist(y, bins='auto')

# %%
f1(10)
# Out:
# mean= -0.2685339473326591

# %%
f1(100)
# Out:
# mean= -0.08255232563024896

# %%
f1(1000)
# Out:
# mean= -0.13412180978405872

# %%
# mean is dependent of the samples taken

# %% [markdown]
# ## (b)

# %%
def f2(N):
    A = 1.00/10
    n = np.random.random_sample(N)
    n = n*7
    y = np.cos(0.25*np.pi*n)*A
    print('mean= '+ str(y.mean()))
    plt.hist(y, bins='auto')

# %%
f2(10)
# Out:
# mean= 0.03321570040901719

# %%
f2(100)
# Out:
# mean= -0.010186895408960152

# %%
f2(1000)
# Out:
# mean= -0.014768371707139289

# %%
# mean is dependent of the samples taken

# %% [markdown]
# ## (c)

# %%
def f3(N):
    mu = 0
    sigma = 1
    x = np.random.normal(mu,sigma,N)
    print('mean= '+ str(x.mean()))
    num_bins = 100
    n, bins, patches = plt.hist(x, num_bins,  density = 1)  
    y = ((1 / (np.sqrt(2 * np.pi) * sigma)) *np.exp(-0.5 * (1 / sigma * (bins - mu))**2)) 
    plt.plot(bins, y, '--', color ='red')
    plt.show()

# %%
f3(1000)
# Out:
# mean= -0.03241922377112508

# %%
f3(10000)
# Out:
# mean= 0.0023536149331469546

# %%
f3(100000)
# Out:
# mean= 0.002731476984605585
